# %%
# import pymysql

# connection = pymysql.connect(
#         host="127.0.0.1",    # DBMS 의 ip(host) : str
#         port=3306,           # DBMS의 port 번호: int
#         user='root',        # username: str
#         password="1111",    # password: str
#         db="test",
#         charset="utf8",
#         cursorclass=pymysql.cursors.DictCursor)
# try:
#     with connection.cursor() as cursor:
#         create_sql = """
#         create table oil_staion (
#         id INT AUTO_INCREMENT PRIMARY KEY,
#         station_name varchar(20),
#         address varchar(40),
#         brand varchar(10),
#         gasolin_price INT,
#         diesel_price INT,
#         self_service BOOLEAN,
#         car_wash BOOLEAN,
#         convenience_store BOLLEAN,
#         24_hour BOOLEAN
#         );
#         """
#         cursor.execute(create_sql)
#         connection.commit()
# finally :
#     connection.close()

# %%
import pandas as pd
import pymysql

# CSV 파일 읽기
csv_path = r"C:\Users\Playdata\Documents\SKN13-1st-3Team\crawling\주유소정보.csv"
df = pd.read_csv(csv_path, encoding='utf-8')

df = df.rename(columns={
    '이름': 'station_name',
    '주소': 'address',
    '브랜드': 'brand',
    '지역': 'region',
    '휘발유': 'gasoline_price',
    '경유': 'diesel_price',
    '셀프': 'self_service',
    '세차': 'car_wash',
    '편의점': 'convenience_store',
    '24시간': 'hours_24'
})
# Out:
#     지역                   이름                       주소       브랜드    휘발유     경유  \
# 0  강남구          (주)보성 세곡주유소     서울 강남구 헌릉로 731 (세곡동)     SK에너지  1,638  1,528
# 1  강남구             오일프러스 셀프  서울 강남구 남부순환로 2651 (도곡동)     SK에너지  1,679  1,579
# 2  강남구        지에스칼텍스㈜ 은마주유소          서울 강남구 영동대로 235     GS칼텍스  1,679  1,659
# 3  강남구  HD현대오일뱅크㈜직영 강남셀프주유소           서울 강남구 도곡로 208  HD현대오일뱅크  1,684  1,604
# 4  강남구  HD현대오일뱅크㈜직영 도곡셀프주유소        서울 강남구 남부순환로 2718  HD현대오일뱅크  1,684  1,589
#
#   셀프 세차 편의점 24시간
# 0  Y  Y   N    N
# 1  Y  Y   N    Y
# 2  N  Y   N    N
# 3  Y  Y   N    N
# 4  Y  Y   N    N

# %%
# !pip install sqlalchemy pymysql pandas
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 40.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# CSV 파일 읽기
csv_path = r"C:\Users\Playdata\Documents\SKN13-1st-3Team\crawling\주유소정보.csv"
df = pd.read_csv(csv_path, encoding='utf-8-sig')

df = df.rename(columns={
    '이름': 'station_name',
    '주소': 'address',
    '지역': 'region',
    '브랜드': 'brand',
    '휘발유': 'gasoline_price',
    '경유': 'diesel_price',
    '셀프': 'self_service',
    '세차': 'car_wash',
    '편의점': 'convenience_store',
    '24시간': 'hours_24'
})

df['gasoline_price'] = df['gasoline_price'].str.replace(',', '').astype(int)
df['diesel_price'] = df['diesel_price'].str.replace(',', '').astype(int)

conn = pymysql.connect(
        host='127.0.0.1', # DB 주소 (예: '127.0.0.1' 또는 AWS RDS 주소)
        port = 3306,
        user='root',    # MySQL 사용자
        password='1111',
        database='gas_station',  # 저장할 데이터베이스명
    )

engine = create_engine("mysql+pymysql://root:1111@127.0.0.1:3306/gas_station")

df.to_sql(name='gas_station', con=engine, if_exists='append', index=False)

print("데이터 저장 완료!")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\sqlalchemy\engine\base.py:1933, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932     if not evt_handled:
# -> 1933         self.dialect.do_executemany(
#    1934             cursor,
#    1935             str_statement,
#    1936             effective_parameters,
#    1937             context,
#    1938         )
#    1939 elif not effective_parameters and context.no_parameters:
#
# File ~\miniconda3\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:172, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     171 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 172     rowcount = cursor.executemany(statement, parameters)
#     173     if context is not None:
#
# ...

# %%
import pandas as pd
# from sqlalchemy import create_engine
import pymysql

# CSV 파일 읽기
csv_path = r"C:\Users\Playdata\Documents\SKN13-1st-3Team\crawling\주유소정보.csv"
df = pd.read_csv(csv_path, encoding='utf-8-sig')

df['gasoline_price'] = df['gasoline_price'].str.replace(',', '').astype(int)
df['diesel_price'] = df['diesel_price'].str.replace(',', '').astype(int)

conn = pymysql.connect(
        host='127.0.0.1', # DB 주소 (예: '127.0.0.1' 또는 AWS RDS 주소)
        port = 3306,
        user='root',    # MySQL 사용자
        password='1111',
        database='gas_station',  # 저장할 데이터베이스명
    )

engine = create_engine(
    f"mysql+pymysql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}?charset=utf8mb4"
)

cursor = conn.cursor()

insert_sql = "insert into gas_station (station_name, address, brand, region, gasolin_price, diesel_price, self_service, car_wash, convenience_store, hours_24) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

with pymysql.connect(host='127.0.0.1', port = 3306, user='root', password='1111', database='gas_station') as conn:
    with conn.cursor() as cursor :
       result = cursor.execute(insert_sql, ["(주)보성 세곡주유소", "서울 강남구 헌릉로 731 (세곡동)", "SK에너지", "강남구", 1638, 1528, True, True, False, False])
       conn.commit()
        
print("처리 행수:",result)
# Out:
# 처리 행수: 1

# %%
import pandas as pd
import pymysql

# CSV 파일 읽기
#csv_path = r"C:\Users\Playdata\Documents\SKN13-1st-3Team\crawling\주유소정보.csv"
#df = pd.read_csv(csv_path, encoding='utf-8')

# MySQL 연결 설정

try :
    conn = pymysql.connect(
        host='127.0.0.1', # DB 주소 (예: '127.0.0.1' 또는 AWS RDS 주소)
        port = 3306,
        user='root',    # MySQL 사용자
        password='1111',
        database='gas_station',  # 저장할 데이터베이스명
    )

    cursor = conn.cursor()

    insert_sql = "insert into gas_station (station_name, address, brand, gasolin_price, diesel_price, self_service, car_wash, convenience_store, hours_24) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

    with pymysql.connect(host='127.0.0.1', port = 3306, user='root', password='1111', database='gas_station') as conn:
        with conn.cursor() as cursor :
            result = cursor.execute(insert_sql, ["(주)보성 세곡주유소", "서울 강남구 헌릉로 731 (세곡동)", "SK에너지", "강남구", 1638, 1528, "Y", "Y", "N", "N"])
            conn.commit()
        
    print("처리 행수:",result)
    
finally:
    if conn:
        cursor.close()

# SQLAlchemy 엔진 생성
# engine = create_engine(
#     f"mysql+pymysql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}?charset=utf8mb4"
# )


# 데이터베이스에 저장
# for index, row in df.iterrows():
#     cursor.execute("""
#         INSERT INTO gas_station (station_name, address, brand, gasolin_price, diesel_price,  updated_at)
#         VALUES (%s, %s, %s, %s, %s)
#     """, (row['상호'], row['주소'], row['상표'], row['휘발유'], row['수정일자']))

# conn.commit()
#     print(f"성공! {len(df)}개의 주유소 데이터가 저장되었습니다.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[4], line 25
#      23 with pymysql.connect(host='127.0.0.1', port = 3306, user='root', password='1111', database='gas_station') as conn:
#      24     with conn.cursor() as cursor :
# ---> 25         result = cursor.execute(insert_sql, ["(주)보성 세곡주유소", "서울 강남구 헌릉로 731 (세곡동)", "SK에너지", "강남구", 1638, 1528, "Y", "Y", "N", "N"])
#      26         conn.commit()
#      28 print("처리 행수:",result)
#
# File ~\miniconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\miniconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
# ...

# %%
insert_sql = "insert into gas_staion (station_name, address, brand, gasolin_price, diesel_price, self_service, car_wash, convenience_store, hours_24) values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"

with pymysql.connect(host='127.0.0.1', port = 3306, user='root', password='1111', database='gas_station') as conn:
    with conn.cursor() as cursor :
        result = cursor.execute(insert_sql, ["(주)보성 세곡주유소", "서울 강남구 헌릉로 731 (세곡동)", "SK에너지", "강남구", 1638, 1528, "Y", "Y", "N", "N"])
        conn.commit()
        
print("처리 행수:",result)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[21], line 5
#       3 with pymysql.connect(host='127.0.0.1', port = 3306, user='root', password='1111', database='gas_station') as conn:
#       4     with conn.cursor() as cursor :
# ----> 5         result = cursor.execute(insert_sql, ["(주)보성 세곡주유소", "서울 강남구 헌릉로 731 (세곡동)", "SK에너지", "강남구", 1638, 1528, "Y", "Y", "N", "N"])
#       6         conn.commit()
#       8 print("처리 행수:",result)
#
# File ~\miniconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File ~\miniconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
# ...
